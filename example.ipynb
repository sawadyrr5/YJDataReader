# %%
from YJDataReader.io.data import DataReader

split = DataReader(8411, data_source='yahoojp_split')
split
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Volume</th>
#     </tr>
#     <tr>
#       <th>Code</th>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="12" valign="top">8411</th>
#       <th>2008-12-19</th>
#       <td>259400</td>
#       <td>270600</td>
#       <td>253200</td>
#       <td>259900</td>
#       <td>281076</td>
#     </tr>
#     <tr>
#       <th>2008-12-22</th>
#       <td>266400</td>
#       <td>276000</td>
# ...

# %%
bars = DataReader(8411, data_source='yahoojp', start='2008-12-19', end='2009-01-17', adjust=False)
bars
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Volume</th>
#     </tr>
#     <tr>
#       <th>Code</th>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="12" valign="top">8411</th>
#       <th>2008-12-19</th>
#       <td>259400</td>
#       <td>270600</td>
#       <td>253200</td>
#       <td>259900</td>
#       <td>281076</td>
#     </tr>
#     <tr>
#       <th>2008-12-22</th>
#       <td>266400</td>
#       <td>276000</td>
# ...

# %%
prof = DataReader(8411, data_source='yahoojp_profile')
prof
# Out:
# {'average_age': '37.7',
#  'average_income': '7440',
#  'ceo_name': '坂井\u3000辰史',
#  'closing': '3月末日',
#  'code': 8411,
#  'company_name_en': 'Ｍｉｚｕｈｏ\u3000Ｆｉｎａｎｃｉａｌ\u3000Ｇｒｏｕｐ，\u3000Ｉｎｃ．',
#  'company_name_jp': 'みずほフィナンシャルグループ',
#  'consolidated_business': '【資金】預金78、金銭信13、他9【資産】現・預け金18、有価証券12、貸出金30、他40【融資】中小企業等向け58、住宅・消費者向け19(2017.3)',
#  'employees_consolidates': '61069',
#  'employees_independent': '30901',
#  'established_date': '2003年1月8日',
#  'exchanges': '東証1部',
#  'hq_address': '〒100-8176 東京都千代田区大手町１−５−５',
#  'ipo_date': '2003年3月12日',
#  'name': '(株)みずほフィナンシャルグループ【8411】',
#  'sector': '銀行業',
#  'specify': '３メガバンクで規模２位。旧富士、第一勧業、日本興業の３行が前身。銀行・信託・証券の連携加速',
#  'telephone': '０３−５２２４−１１１１',
#  'unit_shares': '100'}

# %%
independent = DataReader(8411, data_source='yahoojp_independent')
independent
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>前期</th>
#       <th>2期前</th>
#       <th>3期前</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>決算期</td>
#       <td>2017年3月期</td>
#       <td>2016年3月期</td>
#       <td>2015年3月期</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>会計方式</td>
#       <td>日本方式</td>
#       <td>日本方式</td>
#       <td>日本方式</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>決算発表日</td>
#       <td>2017年5月15日</td>
#       <td>2016年5月13日</td>
#       <td>2015年5月15日</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>決算月数</td>
#       <td>12か月</td>
# ...

# %%
consolidate = DataReader(8411, data_source='yahoojp_consolidate')
consolidate
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>前期</th>
#       <th>2期前</th>
#       <th>3期前</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>決算期</td>
#       <td>2017年3月期</td>
#       <td>2016年3月期</td>
#       <td>2015年3月期</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>会計方式</td>
#       <td>日本方式</td>
#       <td>日本方式</td>
#       <td>日本方式</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>決算発表日</td>
#       <td>2017年5月15日</td>
#       <td>2016年5月13日</td>
#       <td>2015年5月15日</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>決算月数</td>
#       <td>12か月</td>
# ...
